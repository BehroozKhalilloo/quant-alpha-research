# %% [markdown]
# # Backtest Analysis
#
# Review long-short returns, transaction costs, drawdown, turnover, and exposure diagnostics from saved artifacts.

# %%
import pandas as pd

returns = pd.read_csv('../data/processed/backtest_returns.csv', index_col=0, parse_dates=True)
summary = pd.read_csv('../data/processed/backtest_summary.csv', index_col=0)
summary
