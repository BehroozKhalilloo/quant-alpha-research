# %% [markdown]
# # Data Exploration
#
# Load downloaded OHLCV data, inspect missingness, universe coverage, dollar volume, and benchmark availability.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from quant_alpha.data import load_market_data

data = load_market_data('../data/raw/ohlcv.csv')
data.head()
